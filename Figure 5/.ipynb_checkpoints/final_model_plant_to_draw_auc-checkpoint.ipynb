# %%
from sklearn.ensemble import RandomForestClassifier
import deepchem as dc
import numpy as np
import pandas as pd
import tempfile
import chemprop
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import backend as K
from tensorflow.keras import initializers
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.linear_model import LogisticRegression
import xgboost
import os
from sklearn.svm import SVC
# Out:
# 2022-11-18 20:12:03.266400: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-18 20:12:03.876737: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-18 20:12:03.876754: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-18 20:12:03.947206: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-18 20:12:05.032229: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-11-18 20:12:05.032316: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-11-18 20:12:05.032323: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
AUC_ROC=[]
model=[]
def list_auc(list_f,list_m):
    main_all_feature=pd.DataFrame()
    for feature in list_f:
        for m in list_m:
            read_main=pd.read_csv('pred_'+m+'_main_set_'+feature+'.csv')
            df_main=pd.DataFrame(read_main)
            pred1=[]
            for p in df_main['pred']:
                if p<=0.5:
                    p=0
                else:
                    p=1
                pred1.append(p)
            main_all_feature.insert(loc=len(main_all_feature.columns),column=m+feature,value=pred1)


    external_all_feature=pd.DataFrame()
    for feature in list_f:
        for m in list_m:
            read_main=pd.read_csv('pred_'+m+'_external_set_'+feature+'.csv')
            df_main=pd.DataFrame(read_main)
            pred1=[]
            for p in df_main['pred']:
                if p<=0.5:
                    p=0
                else:
                    p=1
                pred1.append(p)
            external_all_feature.insert(loc=len(external_all_feature.columns),column=m+feature,value=pred1)
    
    read_m = pd.read_csv("main_set_plus_AtomPairFP.csv")
    df_m = pd.DataFrame(read_m)
    a1 = df_m['active']
    c1=[]
    for b1 in a1:
        if b1==1:
            b1=0
        else:
            b1=1
        c1.append(b1)

    y_m=pd.DataFrame()
    y_m.insert(loc=0, column='active', value=a1)
    y_m.insert(loc=1, column='inactive', value=c1)
    X_m=main_all_feature

    read_e = pd.read_csv("external_set_plus_AtomPairFP.csv")
    df_e = pd.DataFrame(read_e)
    a2 = df_e['active']
    c1=[]
    for b1 in a2:
        if b1==1:
            b1=0
        else:
            b1=1
        c1.append(b1)

    y_e=pd.DataFrame()
    y_e.insert(loc=0, column='active', value=a2)
    y_e.insert(loc=1, column='inactive', value=c1)
    X_e=external_all_feature

    batch_size = 8192
    num_classes = 2
    model = Sequential()
    model.add(Dense(800,
                    activation='relu',
                    input_dim=len(X_m.columns),
                    kernel_initializer = initializers.RandomNormal(stddev=0.02),
                    bias_initializer = initializers.RandomNormal(mean=1.),
                    kernel_regularizer = regularizers.l2(1e-1)))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))
    opt = keras.optimizers.Adam(learning_rate=0.001)

    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=opt,
                  metrics=['AUC'])
    model.fit(X_m, y_m,
              batch_size=batch_size,
              epochs=100)
    score = model.evaluate(X_e, y_e, verbose=0)
    print(score[1])
    AUC_ROC.append(score[1])
    proba=model.predict(X_e,
                      batch_size=None,
                      verbose="auto",
                      steps=None,
                      callbacks=None,
                      max_queue_size=10,
                      workers=1,
                      use_multiprocessing=False)
    pro=[]
    for p in proba:
        pi = p[0]
        pro.append(pi)
    df_external=pd.DataFrame()
    df_external['pred']=pro
    df_external.to_csv('result_to_draw_auc.csv',index=False)
    model=''

# %%
m='all_model'
a=['AtomPairFP','Charge',
       'MAP4','MOE','MorganFP','Topology']
b=['xgb','fcnn','lr','dmpnn']
list_auc(a,b)
# Out:
# 2022-11-18 20:12:15.009698: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-18 20:12:15.011138: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-11-18 20:12:15.011302: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-11-18 20:12:15.011446: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-11-18 20:12:15.011584: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-11-18 20:12:15.011684: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-11-18 20:12:15.013839: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 1/1 [==============================] - 0s 482ms/step - loss: 1.6897 - auc: 0.6304
# Epoch 2/100
# 1/1 [==============================] - 0s 26ms/step - loss: 1.5868 - auc: 0.8000
# Epoch 3/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.5297 - auc: 0.8223
# Epoch 4/100
# 1/1 [==============================] - 0s 27ms/step - loss: 1.3948 - auc: 0.8383
# Epoch 5/100
# 1/1 [==============================] - 0s 29ms/step - loss: 1.2653 - auc: 0.8423
# Epoch 6/100
# 1/1 [==============================] - 0s 32ms/step - loss: 1.1740 - auc: 0.8489
# Epoch 7/100
# 1/1 [==============================] - 0s 31ms/step - loss: 1.1218 - auc: 0.8516
# Epoch 8/100
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0642 - auc: 0.8684
# Epoch 9/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9581 - auc: 0.9127
# Epoch 10/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9014 - auc: 0.9308
# Epoch 11/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8489 - auc: 0.9463
# Epoch 12/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8172 - auc: 0.9523
# Epoch 13/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.7673 - auc: 0.9620
# Epoch 14/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.7537 - auc: 0.9620
# Epoch 15/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.7068 - auc: 0.9699
# Epoch 16/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6667 - auc: 0.9755
# Epoch 17/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6389 - auc: 0.9781
# Epoch 18/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6155 - auc: 0.9801
# Epoch 19/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5964 - auc: 0.9819
# Epoch 20/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5703 - auc: 0.9839
# Epoch 21/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5514 - auc: 0.9848
# Epoch 22/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5317 - auc: 0.9858
# Epoch 23/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5023 - auc: 0.9889
# Epoch 24/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4922 - auc: 0.9885
# Epoch 25/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4698 - auc: 0.9907
# Epoch 26/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4598 - auc: 0.9898
# Epoch 27/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4489 - auc: 0.9899
# Epoch 28/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4429 - auc: 0.9887
# Epoch 29/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4252 - auc: 0.9904
# Epoch 30/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4107 - auc: 0.9904
# Epoch 31/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3950 - auc: 0.9909
# Epoch 32/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3833 - auc: 0.9915
# Epoch 33/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3709 - auc: 0.9924
# Epoch 34/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3613 - auc: 0.9925
# Epoch 35/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3573 - auc: 0.9911
# Epoch 36/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3492 - auc: 0.9908
# Epoch 37/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3390 - auc: 0.9911
# Epoch 38/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3370 - auc: 0.9909
# Epoch 39/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3266 - auc: 0.9911
# Epoch 40/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3232 - auc: 0.9905
# Epoch 41/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3131 - auc: 0.9905
# Epoch 42/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3075 - auc: 0.9899
# Epoch 43/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3113 - auc: 0.9893
# Epoch 44/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2933 - auc: 0.9912
# Epoch 45/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2857 - auc: 0.9918
# Epoch 46/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2882 - auc: 0.9894
# Epoch 47/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2914 - auc: 0.9897
# Epoch 48/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2854 - auc: 0.9896
# Epoch 49/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2773 - auc: 0.9902
# Epoch 50/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2836 - auc: 0.9884
# Epoch 51/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2696 - auc: 0.9905
# Epoch 52/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2678 - auc: 0.9901
# Epoch 53/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2632 - auc: 0.9909
# Epoch 54/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2654 - auc: 0.9893
# Epoch 55/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2780 - auc: 0.9868
# Epoch 56/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2597 - auc: 0.9898
# Epoch 57/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2593 - auc: 0.9894
# Epoch 58/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2566 - auc: 0.9896
# Epoch 59/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2625 - auc: 0.9880
# Epoch 60/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2591 - auc: 0.9890
# Epoch 61/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2488 - auc: 0.9907
# Epoch 62/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2555 - auc: 0.9888
# Epoch 63/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2436 - auc: 0.9909
# Epoch 64/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2430 - auc: 0.9910
# Epoch 65/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2436 - auc: 0.9912
# Epoch 66/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2427 - auc: 0.9916
# Epoch 67/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2445 - auc: 0.9901
# Epoch 68/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2548 - auc: 0.9880
# Epoch 69/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2443 - auc: 0.9905
# Epoch 70/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2452 - auc: 0.9899
# Epoch 71/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2390 - auc: 0.9917
# Epoch 72/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2415 - auc: 0.9908
# Epoch 73/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2392 - auc: 0.9910
# Epoch 74/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2401 - auc: 0.9908
# Epoch 75/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2343 - auc: 0.9919
# Epoch 76/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2389 - auc: 0.9908
# Epoch 77/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2363 - auc: 0.9911
# Epoch 78/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2472 - auc: 0.9892
# Epoch 79/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2322 - auc: 0.9921
# Epoch 80/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2452 - auc: 0.9898
# Epoch 81/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2372 - auc: 0.9914
# Epoch 82/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2439 - auc: 0.9901
# Epoch 83/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.2376 - auc: 0.9906
# Epoch 84/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2348 - auc: 0.9905
# Epoch 85/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2331 - auc: 0.9917
# Epoch 86/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2400 - auc: 0.9905
# Epoch 87/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2408 - auc: 0.9900
# Epoch 88/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2354 - auc: 0.9913
# Epoch 89/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2362 - auc: 0.9910
# Epoch 90/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2390 - auc: 0.9898
# Epoch 91/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2346 - auc: 0.9913
# Epoch 92/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2357 - auc: 0.9900
# Epoch 93/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2290 - auc: 0.9922
# Epoch 94/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2390 - auc: 0.9903
# Epoch 95/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2276 - auc: 0.9924
# Epoch 96/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2304 - auc: 0.9909
# Epoch 97/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2429 - auc: 0.9894
# Epoch 98/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2377 - auc: 0.9900
# Epoch 99/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2378 - auc: 0.9900
# Epoch 100/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2294 - auc: 0.9916
# 0.9514772295951843
# 14/14 [==============================] - 0s 2ms/step
